# %% [markdown]
# # **Lab 1 Manual – AI**
# ### *Introduction to AI & Basic Python Tools*
#
# ---
#
# **Name:** Muhammad Umair Habib
# **Course:** Artificial Intelligence
# **Course Code:** COMP4114
# **Lab Number:** 1
#
# ---

# %% [markdown]
# Task 1: Print Messages in Python

# %%
# Write a simple Python code to print messages.

print("Welcome to AI Lab")
print("This is your first Python Program")

# %% [markdown]
# Task 2: Basic Variables

# %%
# Create variables related to AI concepts.

ai_field = "Artificial Intelligence"
learning_type = "Machine Learning"
year = 2025

print(ai_field)
print(learning_type)
print("Year: ", year)

# %% [markdown]
# Task 3: Simple Math (AI-related example)

# %%
# Computing values is common in AI.

accuracy = 88
improve_accuracy = accuracy + 5
print("New Accuracy: ", improve_accuracy)

# %% [markdown]
# Task 4: List & Dictionary (Data Representation)

# %%
# Lists and dictionaries are used in datasets.

subjects = ["AI", "Ml", "DL"]
info = {
    "topic": "Intro to AI",
    "lab": 1,
    "tools": ["Python", "Numpy"]
}

print(subjects)
print(info)

# %% [markdown]
# Task 5: User Input Example

# %%
# AI systems often take input from users.

name = input("Enter your name: ")
print("Hello " + name + ", welcome to AI.")
